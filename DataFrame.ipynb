# %%
import pandas as pd

s = pd.Series([10, 20, 30, 40, 50])
print(s)



s = pd.Series([10, 20, 30], index=["a", "b", "c"])
print(s)




data = {
    "Name": ["Amit", "Rahul", "Priya"],
    "Age": [20, 21, 19],
    "Marks": [85, 90, 88],
    "Addres":["Jaunpur","Vanarsi","Bhadohi"]
}

df = pd.DataFrame(data)
print(df)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# a    10
# b    20
# c    30
# dtype: int64
#     Name  Age  Marks   Addres
# 0   Amit   20     85  Jaunpur
# 1  Rahul   21     90  Vanarsi
# 2  Priya   19     88  Bhadohi
