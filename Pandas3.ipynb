# %%
# Out:
# 0    55
# 1    60
# 2    35
# 3    40
# dtype: int64

# %%
# impoert pandas number
import pandas as pd
# marks=pd.Series([55,60,35,40])
# print(marks)



# dataFrame  in pandas

data={
    'Name':['Mahesh','Shubham','Amit','Suresh'],
    'Age':[25,21,20,30],
    'City':['Jaunpur','Mumbai','Bangalore','Vanarsi'],
    'Designation':['Student','Teacher','Software Enginering','Cyber scruity']
}

df=pd.DataFrame(data)
print(df)
print(type(df))   # check datatypes
# Out:
#       Name  Age       City          Designation
# 0   Mahesh   25    Jaunpur              Student
# 1  Shubham   21     Mumbai              Teacher
# 2     Amit   20  Bangalore  Software Enginering
# 3   Suresh   30    Vanarsi        Cyber scruity
# <class 'pandas.DataFrame'>
