# %%
# creat 1d array
import numpy as np
arr=np.array ([1,2,3,45])
print(arr)



# 2D array of numpy

arr1=np.array ([[10,20,30,40],[22,44,66,77]])
print(arr1)
# Out:
# [ 1  2  3 45]
# [[10 20 30 40]
#  [22 44 66 77]]

# %%
arr1.itemsize  # total number
arr1.ndim
# Out:
# 2

# %%
print("The type of Arr1 is :",type(arr1))        #check datatype
# Out:
# The type of Arr1 is : <class 'numpy.ndarray'>

# %%
import time 
size=11100000
py_list=list(range(size))
nump_arr=np.array(size)
