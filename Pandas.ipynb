# %%
import pandas as pd

detail={
    'Order id':[123,345,678,908,123,445,667,889],
    'CustomerName':["Shubham","Aryan","Gaurav","ritik","shivam","sanu","Sapan","Amit"],
    'ProductName':["Camputer","Mause","Charger","Moblie","keybord","fandive","i pad","keyboad"],
    'Address':["Jaunpur","Vanrase","Mumbai","Delhi","Bailya","Mirzapur","Babtapur","jamalapur"]
}
df=pd.DataFrame(detail)
# print(df)

df.head(3)   # first 3 row 
df.tail(2)    # last 2 row

df.rename(columns={"Address":"Customer Address"})
# Out:
#    Order id CustomerName ProductName    Address
# 0       123      Shubham    Camputer    Jaunpur
# 1       345        Aryan       Mause    Vanrase
# 2       678       Gaurav     Charger     Mumbai
# 3       908        ritik      Moblie      Delhi
# 4       123       shivam     keybord     Bailya
# 5       445         sanu     fandive   Mirzapur
# 6       667        Sapan       i pad   Babtapur
# 7       889         Amit     keyboad  jamalapur
#    Order id CustomerName ProductName Customer Address
# 0       123      Shubham    Camputer          Jaunpur
# 1       345        Aryan       Mause          Vanrase
# 2       678       Gaurav     Charger           Mumbai
# 3       908        ritik      Moblie            Delhi
# 4       123       shivam     keybord           Bailya
# 5       445         sanu     fandive         Mirzapur
# 6       667        Sapan       i pad         Babtapur
# 7       889         Amit     keyboad        jamalapur
