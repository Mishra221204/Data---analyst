# %%
def add(a,b):
    return a+b

def subs(a,b):
    return a-b

def Multy(a,b):
    return a*b

def division(a,b):
    if b==0:
        return "canot division by zero"
    return a/b


try:
    a=float(input("Enter a first number"))
    b=float(input("Enter a secand number"))



print("1.Addition")
print("2.Substraction")
print("3.Multiply")
print("4.division")


choice= int(input("Enter your choice:"))

if choice==1:
    print("Addition=",add(a,b))

elif choice==2:
    print("Substraction=",subs(a,b))

elif choice==3:
    print("Multiply=",Multy(a,b))


elif choice==1:
    print("Division=",division(a,b))


else:
    print("Invalid choice value")


except ValueError:
     print("please enter valid number")

except ZeroDivisionError:
print("Canot divide by zero")
